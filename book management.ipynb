# %%
#################################       BOOK MANAGEMENT SYSTEM   #########################################
book_id=set()
books= {
    101: {"name": "Wings of Fire", "author": "A. P. J. Abdul Kalam"},
    102: {"name": "The Alchemist", "author": "Paulo Coelho"},
    103: {"name": "Rich Dad Poor Dad", "author": "Robert Kiyosaki"},
    104: {"name": "Think and Grow Rich", "author": "Napoleon Hill"},
    105: {"name": "Harry Potter and the Philosopher’s Stone", "author": "J. K. Rowling"},
    106: {"name": "The Power of Habit", "author": "Charles Duhigg"},
    107: {"name": "Atomic Habits", "author": "James Clear"},
    108: {"name": "Ikigai", "author": "Hector Garcia & Francesc Miralles"},
    109: {"name": "The Monk Who Sold His Ferrari", "author": "Robin Sharma"},
    110: {"name": "The Theory of Everything", "author": "Stephen Hawking"}
}
# initialize set with existing ids
book_id = set(books.keys())
#adding of a book
def add_books():
    id=int(input("enter book id"))
    if id in book_id:
       print("book already exists")
    else:
         name=input("enter name of the book")
         author=input("enter name of author")
         book_id.add(id)
         books[id]={"name":name,"author":author}
         print("book successfully added")
#updating a book
def update():
    old_id = int(input("enter the book id "))
    if old_id in book_id:
        new_id =int( input("enter new id "))
        name = input("enter new book name")
        author = input("enter the new author name")
        book_id.remove(old_id)
        del books[old_id]
        book_id.add(new_id)
        books[new_id] = {"name":name, "author":author}
        print("book updated successfully")
    else:
        print("book not found")
#deleting a book
def delete():
    id=int(input("enter the id u want to delete"))
    if id in book_id:
        book_id.remove(id)
        del books[id]
        print("book succeesfully deleted")
    else:
        print("book not found")
#total books
def total_books():
    print("the total no of books are",len(book_id))
#display all books
def display():
    if not books:
        print("No books are available")
    else:    
        for id,details in books.items():
            print(id,":",details["name"],":",details["author"])
def main():
    while True:
        print("\n1.Add book\n2.update\n3.Delete\n4.total_books\n5.display\n6.exit")
        choice = input("Enter choice: ")
        if choice == "1":
            add_books()
        elif choice == "2":
             update()
        elif choice == "3":
              delete()
        elif choice == "4":
             total_books()
        elif choice == "5":
             display()
        elif choice=="6":
             break
        else:
            print("Invalid choice")
if __name__ == "__main__":
    main()
# Out:
# 1.Add book
# 2.update
# 3.Delete
# 4.total_books
# 5.display
# 6.exit
# Enter choice:  5
# 101 : Wings of Fire : A. P. J. Abdul Kalam
# 102 : The Alchemist : Paulo Coelho
# 103 : Rich Dad Poor Dad : Robert Kiyosaki
# 104 : Think and Grow Rich : Napoleon Hill
# 105 : Harry Potter and the Philosopher’s Stone : J. K. Rowling
# 106 : The Power of Habit : Charles Duhigg
# 107 : Atomic Habits : James Clear
# 108 : Ikigai : Hector Garcia & Francesc Miralles
# 109 : The Monk Who Sold His Ferrari : Robin Sharma
# 110 : The Theory of Everything : Stephen Hawking
#
# 1.Add book
# 2.update
# 3.Delete
# 4.total_books
# 5.display
# 6.exit
# Enter choice:  6

# %%
phone_book = {}
name = input("Enter name: ")
number = input("Enter phone number: ")
def add_contact():
    if name not in phonebook:
        phone_book[name] = number
        print("Contact added")
    else:
        print("already exists")
def search_contact():
    name = input("Enter name to search: ")
    if name in phone_book:
        print(name, ":", phone_book[name])
    else:
        print("Contact not found")
def delete_contact():
    name = input("Enter name to delete: ")
    if name in phone_book:
        del phone_book[name]
        print("Contact deleted")
    else:
        print("Contact not found")
def display_contacts():
    if not phone_book:
        print("Phone book is empty")
    else:
        for name, number in phone_book.items():
            print(name, ":", number)
def main():
    while True:
        print("\n1.Add  2.Search  3.Delete  4.Display  5.Exit")
        choice = input("Enter choice: ")

        if choice == "1":
            add_contact()
        elif choice == "2":
            search_contact()
        elif choice == "3":
            delete_contact()
        elif choice == "4":
            display_contacts()
        elif choice == "5":
            break
        else:
            print("Invalid choice")

if __name__ == "__main__":
    main()
# Out:
# Enter name:  navya
# Enter phone number:  81211820[0768
# 1.Add  2.Search  3.Delete  4.Display  5.Exit
# Enter choice:  5
